# %%
import pandas as pd
import sklearn as sk
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import svm
from sklearn.model_selection import cross_val_score
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import StandardScaler
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import mean_absolute_error
import matplotlib.pyplot as plt

def consertaPreco(preco):
    preco = preco.split(',')[0]
    preco = preco.replace('$','')
    return float(preco)

[[1873.54]]

#Ajeitando o dataSet
itens = pd.read_csv('items.csv').dropna()
x = itens[["rating","totalReviews"]]
y = itens.apply(lambda row: consertaPreco(row["prices"]), axis=1)

print(y)
print(x)
# Out:
# 1       49.95
# 6       78.99
# 8       99.99
# 9       59.89
# 10      99.95
#         ...
# 787    999.95
# 788    304.99
# 789    519.99
# 790    139.99
# 791     74.99
# Length: 577, dtype: float64
#      rating  totalReviews
# 1       2.9             7
# 6       2.0             1
# 8       3.2             8
# 9       3.5           133
# 10      2.9             2
# ..      ...           ...
# 787     3.7            50
# 788     4.7             7
# 789     2.0             1
# 790     3.0             5
# 791     4.0             1
#
# [577 rows x 2 columns]

# %%
#Dividindo 70% treino e 30% teste com semente 9
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.3,random_state = 9)

print(x_train)
print(y_train)
print(x_test)
print(y_test)
# Out:
#      rating  totalReviews
# 726     4.4           385
# 386     3.9            89
# 89      3.6           422
# 518     3.6            21
# 429     4.0             1
# ..      ...           ...
# 244     3.5           284
# 133     3.1           623
# 710     4.3           368
# 530     4.7             4
# 570     3.7            27
#
# [403 rows x 2 columns]
# 726    182.00
# 386    135.55
# 89     169.00
# 518    348.35
# 429    373.00
#         ...
# 244    217.99
# 133    153.00
# 710    618.95
# 530     83.99
# 570    124.99
# Length: 403, dtype: float64
#      rating  totalReviews
# 197     3.5             1
# 101     3.4           530
# 154     3.5            36
# 585     3.8            24
# 206     3.2           410
# ..      ...           ...
# 331     2.5             4
# 431     3.9            57
# 336     4.0           168
# 660     4.3           298
# 456     4.1           104
#
# [174 rows x 2 columns]
# 197    299.99
# 101    159.99
# 154     99.00
# 585     87.98
# ...

# %%
#Regressão Linear
regressao = LinearRegression().fit(x_train, y_train)

score = regressao.score(x_train, y_train)

previsoes = regressao.predict(x_test)

print(previsoes)
# Out:
# [243.68704568 230.67923191 243.10477577 255.92607118 224.26114588
#  222.50121911 254.66171366 263.27578907 259.76729295 245.58006271
#  227.53673403 238.23210444 239.24691771 222.63430938 247.69463028
#  243.55395541 247.11060075 230.48311576 220.58452731 259.70074782
#  209.99601308 180.49556421 277.21171544 205.04016034 243.55395541
#  255.4103464  221.60285982 239.13046373 247.72790285 294.07386802
#  267.948825   264.10760322 252.23105671 240.99020819 138.50654559
#  216.89655133 230.94893168 226.77498425 272.22259013 247.82772055
#  270.95823262 218.16090884 251.16985383 256.24216056 214.15332424
#  278.20813281 270.39259899 218.24409026 222.61767309 260.1166549
#  272.75495119 235.18942425 254.34562428 180.57874562 254.34562428
#  253.11453933 222.65094566 256.00925259 306.77870945 243.30265154
#  246.3970002  256.20888799 250.07185915 221.0836158  234.2577924
#  243.40422886 258.40311774 248.5413211  239.21364514 234.32257791
# ...

# %%
#Erro médio

erroMedio = mean_absolute_error(y_test, previsoes)

#Coeficiente e interceptação
print(regressao.intercept_)
print(regressao.coef_)

print(erroMedio)
# Out:
# 96.45098183182546
# [ 4.20722000e+01 -1.66362831e-02]
# 112.57092981699577

# %%
#Validação Cruzada

classificador = GaussianNB()


validacao = cross_val_score(classificador, x, y, cv = 10)
print(validacao.mean())
# Out:
# nan
# c:\users\yann\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Unknown label type: (array([  1.  ,  22.99,  23.99,  24.5 ,  32.95,  48.  ,  49.99,  54.99,
#         56.15,  59.99,  68.  ,  69.49,  69.95,  69.99,  70.99,  72.97,
#         74.99,  77.  ,  78.74,  79.  ,  79.95,  80.  ,  83.99,  84.95,
#         84.99,  87.59,  87.98,  88.95,  88.98,  89.99,  91.99,  92.  ,
#         94.11,  94.99,  95.  ,  96.54,  98.95,  99.  ,  99.95,  99.99,
#        101.  , 102.97, 103.74, 104.  , 104.96, 105.  , 107.55, 107.7 ,
#        108.99, 109.5 , 109.95, 109.99, 110.  , 110.95, 112.36, 112.95,
#        114.4 , 114.99, 117.  , 119.  , 119.96, 119.99, 121.99, 122.5 ,
#        123.99, 124.41, 124.55, 124.99, 125.  , 125.55, 125.95, 125.99,
# ...
